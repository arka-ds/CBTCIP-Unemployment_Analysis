# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('unemployment.csv')
df
# Out:
#              Region        Date Frequency  Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh  31-05-2019   Monthly                             3.65
# 1    Andhra Pradesh  30-06-2019   Monthly                             3.05
# 2    Andhra Pradesh  31-07-2019   Monthly                             3.75
# 3    Andhra Pradesh  31-08-2019   Monthly                             3.32
# 4    Andhra Pradesh  30-09-2019   Monthly                             5.17
# ..              ...         ...       ...                              ...
# 749     West Bengal  29-02-2020   Monthly                             7.55
# 750     West Bengal  31-03-2020   Monthly                             6.67
# 751     West Bengal  30-04-2020   Monthly                            15.63
# 752     West Bengal  31-05-2020   Monthly                            15.22
# 753     West Bengal  30-06-2020   Monthly                             9.86
#
# ...

# %%
df.shape
# Out:
# (754, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 754 entries, 0 to 753
# Data columns (total 7 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Region                                   740 non-null    object
#  1   Date                                     740 non-null    object
#  2   Frequency                                740 non-null    object
#  3   Estimated Unemployment Rate (%)          740 non-null    float64
#  4   Estimated Employed                       740 non-null    float64
#  5   Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                     740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 41.4+ KB

# %%
df.isnull().any()
# Out:
# Region                                     True
# Date                                       True
# Frequency                                  True
# Estimated Unemployment Rate (%)            True
# Estimated Employed                         True
# Estimated Labour Participation Rate (%)    True
# Area                                       True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Region                                     14
# Date                                       14
# Frequency                                  14
# Estimated Unemployment Rate (%)            14
# Estimated Employed                         14
# Estimated Labour Participation Rate (%)    14
# Area                                       14
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# Region                                     0
# Date                                       0
# Frequency                                  0
# Estimated Unemployment Rate (%)            0
# Estimated Employed                         0
# Estimated Labour Participation Rate (%)    0
# Area                                       0
# dtype: int64

# %%
df.duplicated().any()
# Out:
# np.False_

# %%
df.columns
# Out:
# Index(['Region', 'Date', 'Frequency', 'Estimated Unemployment Rate (%)',
#        'Estimated Employed', 'Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
df.rename(columns = { 'Region' : 'States'}, inplace = True)

# %%
df.columns
# Out:
# Index(['States', 'Date', 'Frequency', 'Estimated Unemployment Rate (%)',
#        'Estimated Employed', 'Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
average_unemployment_rate = df.groupby('States')['Estimated Unemployment Rate (%)'].mean()
print('average_unemployment_rate in india is :', average_unemployment_rate)
# Out:
# average_unemployment_rate in india is : States
# Andhra Pradesh       7.477143
# Assam                6.428077
# Bihar               18.918214
# Chandigarh          15.991667
# Chhattisgarh         9.240357
# Delhi               16.495357
# Goa                  9.274167
# Gujarat              6.663929
# Haryana             26.283214
# Himachal Pradesh    18.540357
# Jammu & Kashmir     16.188571
# Jharkhand           20.585000
# Karnataka            6.676071
# Kerala              10.123929
# Madhya Pradesh       7.406429
# Maharashtra          7.557500
# Meghalaya            4.798889
# Odisha               5.657857
# Puducherry          10.215000
# Punjab              12.031071
# Rajasthan           14.058214
# Sikkim               7.249412
# Tamil Nadu           9.284286
# Telangana            7.737857
# Tripura             28.350357
# Uttar Pradesh       12.551429
# Uttarakhand          6.582963
# West Bengal          8.124643
# ...

# %%
#Name of the state with highest unemployment rate

name_of_state_highest_unemployment_rate = average_unemployment_rate.idxmax()
print('Name of the state with highest unemployment rate :', name_of_state_highest_unemployment_rate)
# Out:
# Name of the state with highest unemployment rate : Tripura

# %%
#Highest Unemployment rate of that state
highest_unemployment_rate = average_unemployment_rate.max()
print('Highest Unemployment Rate :', highest_unemployment_rate)
# Out:
# Highest Unemployment Rate : 28.350357142857142

# %%
#Name of the state with lowest unemployment rate
name_of_state_lowest_unemployment_rate = average_unemployment_rate.idxmin()
print('Name of the state with lowest unemployment rate :', name_of_state_lowest_unemployment_rate)
# Out:
# Name of the state with lowest unemployment rate : Meghalaya

# %%
#Lowest Unemployment rate of that state
lowest_unemployment_rate = average_unemployment_rate.min()
print('Lowest Unemployment Rate :', lowest_unemployment_rate)
# Out:
# Lowest Unemployment Rate : 4.7988888888888885

# %%
# Visualization of unemployment over the time
sns.lineplot(x='Date', y='Estimated Unemployment Rate (%)', data=df)
plt.xticks(rotation=45)
plt.title('Unemployment Rate Over Time')
plt.show()

# %%
df.columns
# Out:
# Index(['States', 'Date', 'Frequency', 'Estimated Unemployment Rate (%)',
#        'Estimated Employed', 'Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
#Barchart to understand state wise unemployment rate
plt.figure(figsize=(10, 6))
plt.bar(df['States'], df['Estimated Unemployment Rate (%)'], color='DeepSkyBlue')
plt.xlabel('States')
plt.ylabel('Estimated Unemployment Rate (%)')
plt.title('Unemployment Rate by State')
plt.xticks(rotation=90)
plt.show()
